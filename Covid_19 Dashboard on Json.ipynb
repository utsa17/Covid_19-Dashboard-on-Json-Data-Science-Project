# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
import folium

# %%
Covid19=pd.read_json('india_statewise.json')
Covid19.head()
# Out:
#                success                                               data  \
# lastRefreshed     True                           2020-07-12T03:54:15.207Z
# source            True                                   covid19india.org
# statewise         True  [{'state': 'Maharashtra', 'confirmed': 246600,...
# total             True  {'confirmed': 850358, 'recovered': 536231, 'de...
#
#                           lastRefreshed          lastOriginUpdate
# lastRefreshed  2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z
# source         2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z
# statewise      2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z
# total          2020-07-12T03:54:15.207Z  2020-07-12T03:54:15.207Z

# %% [markdown]
# # Normalizing Json file

# %%
df_india = pd.io.json.json_normalize(Covid19['data']['statewise'])
df_india
# Out:
# C:\Users\mukes\AppData\Local\Temp\ipykernel_10884\3917522563.py:1: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead.
#   df_india = pd.io.json.json_normalize(Covid19['data']['statewise'])
#                                        state  confirmed  recovered  deaths  \
# 0                                Maharashtra     246600     136985   10116
# 1                                 Tamil Nadu     134226      85915    1898
# 2                                      Delhi     110921      87692    3334
# 3                                    Gujarat      41027      28685    2033
# 4                              Uttar Pradesh      35092      22689     913
# 5                                  Karnataka      36216      14718     615
# 6                                  Telangana      33402      20919     348
# 7                                West Bengal      28453      17959     906
# 8                             Andhra Pradesh      27235      14393     309
# 9                                  Rajasthan      23748      17869     503
# 10                                   Haryana      20582      15394     297
# 11                            Madhya Pradesh      17201      12679     644
# 12                                     Assam      16072      10427      37
# 13                                     Bihar      15039      10991     118
# 14                                    Odisha      12526       8360      79
# 15                         Jammu and Kashmir      10156       5895     169
# 16                                    Punjab       7587       5040     195
# 17                                    Kerala       7439       3963      30
# 18                          State Unassigned       3416          0       0
# 19                              Chhattisgarh       3897       3070      17
# 20                               Uttarakhand       3417       2718      46
# 21                                 Jharkhand       3663       2256      24
# 22                                       Goa       2368       1428      12
# 23                                   Tripura       1962       1375       2
# 24                                   Manipur       1593        843       0
# 25                                Puducherry       1336        690      18
# 26                          Himachal Pradesh       1182        895      10
# 27                                    Ladakh       1077        928       1
# 28                                  Nagaland        748        313       0
# 29                                Chandigarh        549        413       8
# 30  Dadra and Nagar Haveli and Daman and Diu        482        237       1
# 31                         Arunachal Pradesh        341        125       2
# 32                                   Mizoram        227        150       0
# 33               Andaman and Nicobar Islands        156         92       0
# 34                                    Sikkim        160         80       0
# 35                                 Meghalaya        262         45       2
# 36                               Lakshadweep          0          0       0
#
#     active
# 0    99202
# 1    46413
# 2    19895
# 3    10309
# 4    11490
# 5    20879
# 6    12135
# 7     9588
# 8    12533
# 9     5376
# 10    4891
# 11    3878
# 12    5605
# 13    3930
# 14    4087
# 15    4092
# 16    2352
# 17    3442
# 18    3416
# 19     810
# 20     623
# 21    1383
# 22     928
# 23     571
# 24     750
# 25     628
# 26     264
# 27     148
# 28     435
# 29     128
# 30     240
# 31     214
# 32      77
# 33      64
# 34      67
# 35     215
# 36       0

# %%
df_india.set_index('state',inplace=True)
df_india.head()
# Out:
#                confirmed  recovered  deaths  active
# state
# Maharashtra       246600     136985   10116   99202
# Tamil Nadu        134226      85915    1898   46413
# Delhi             110921      87692    3334   19895
# Gujarat            41027      28685    2033   10309
# Uttar Pradesh      35092      22689     913   11490

# %%
df_india.drop('State Unassigned',inplace=True)

# %%
locations = {
    "Kerala" : [10.8505,76.2711],
    "Maharashtra" : [19.7515,75.7139],
    "Karnataka": [15.3173,75.7139],
    "Telangana": [18.1124,79.0193],
    "Uttar Pradesh": [26.8467,80.9462],
    "Rajasthan": [27.0238,74.2179],
    "Gujarat":[22.2587,71.1924],
    "Delhi" : [28.7041,77.1025],
    "Punjab":[31.1471,75.3412],
    "Tamil Nadu": [11.1271,78.6569],
    "Haryana": [29.0588,76.0856],
    "Madhya Pradesh":[22.9734,78.6569],
    "Jammu and Kashmir":[33.7782,76.5762],
    "Ladakh": [34.1526,77.5770],
    "Andhra Pradesh":[15.9129,79.7400],
    "West Bengal": [22.9868,87.8550],
    "Bihar": [25.0961,85.3131],
    "Chhattisgarh":[21.2787,81.8661],
    "Chandigarh":[30.7333,76.7794],
    "Uttarakhand":[30.0668,79.0193],
    "Himachal Pradesh":[31.1048,77.1734],
    "Goa": [15.2993,74.1240],
    "Odisha":[20.9517,85.0985],
    "Andaman and Nicobar Islands": [11.7401,92.6586],
    "Puducherry":[11.9416,79.8083],
    "Manipur":[24.6637,93.9063],
    "Mizoram":[23.1645,92.9376],
    "Assam":[26.2006,92.9376],
    "Meghalaya":[25.4670,91.3662],
    "Tripura":[23.9408,91.9882],
    "Arunachal Pradesh":[28.2180,94.7278],
    "Jharkhand" : [23.6102,85.2799],
    "Nagaland": [26.1584,94.5624],
    "Sikkim": [27.5330,88.5122],
    "Dadra and Nagar Haveli and Daman and Diu":[20.1809,73.0169],
    "Lakshadweep":[10.5667,72.6417],
}

# %%
df_india['Lat'] = ""
df_india['Long'] = ""
for index in df_india.index:
    df_india.loc[df_india.index==index,'Lat'] = locations[index][0]
    df_india.loc[df_india.index==index,'Long'] = locations[index][1]

# %%
df_india.head()
# Out:
#                confirmed  recovered  deaths  active      Lat     Long
# state
# Maharashtra       246600     136985   10116   99202  19.7515  75.7139
# Tamil Nadu        134226      85915    1898   46413  11.1271  78.6569
# Delhi             110921      87692    3334   19895  28.7041  77.1025
# Gujarat            41027      28685    2033   10309  22.2587  71.1924
# Uttar Pradesh      35092      22689     913   11490  26.8467  80.9462

# %%
india = folium.Map(location=[23,80],tiles='cartodbpositron',zoom_start=4,max_zoom=7,min_zoom=4,height=500,width='80%')

# %%
india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f0bfead76e182ae06acdcf4105773659 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f0bfead76e182ae06acdcf4105773659&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f0bfead76e182ae06acdcf4105773659 = L.map(
#                 &quot;map_f0bfead76e182ae06acdcf4105773659&quot;,
#                 {
#                     center: [23.0, 80.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_96b28e046e7530896af131d694baad34 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 7, &quot;maxZoom&quot;: 7, &quot;minZoom&quot;: 4, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f0bfead76e182ae06acdcf4105773659);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# # Displaying Folium Map using marker and passing values to it

# %%
for i in range(0,len(df_india[df_india['confirmed']>0].index)):
    
    folium.Circle(    
            location=[df_india.iloc[i]['Lat'],df_india.iloc[i]['Long']],
            tooltip="<h5>"+df_india.iloc[i].name+"</h5>"+
            "<li>Confirmed:"+str(df_india.iloc[i]['confirmed'])+"</li>"+
        "<li>Recovered:"+str(df_india.iloc[i]['recovered'])+"</li>"+
            "<li>Deaths:"+str(df_india.iloc[i]['deaths'])+"</li>"+
            "<li>Active:"+str(df_india.iloc[i]['active'])+"</li>",
        radius=(int((df_india.iloc[i]['confirmed']))*0.5),
            color = '#ff6600',
            fill_color = '#ff6600',
            fill=True).add_to(india)
india
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_819b24c4e1d82d7dbc8bf9794b1b9b00 {
#                     position: relative;
#                     width: 80.0%;
#                     height: 500.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_819b24c4e1d82d7dbc8bf9794b1b9b00&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_819b24c4e1d82d7dbc8bf9794b1b9b00 = L.map(
#                 &quot;map_819b24c4e1d82d7dbc8bf9794b1b9b00&quot;,
#                 {
#                     center: [23.0, 80.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dae8496a2aa9946dbb6c772ea51d428 = L.tileLayer(
#                 &quot;https://cartodb-basemaps-{s}.global.ssl.fastly.net/light_all/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;http://cartodb.com/attributions\&quot;\u003eCartoDB\u003c/a\u003e, CartoDB \u003ca href =\&quot;http://cartodb.com/attributions\&quot;\u003eattributions\u003c/a\u003e&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 7, &quot;maxZoom&quot;: 7, &quot;minZoom&quot;: 4, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_819b24c4e1d82d7dbc8bf9794b1b9b00);
#
#
#             var circle_cd5b1df9199f38c383457ba51d9e7a9c = L.circle(
#                 [19.7515, 75.7139],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff6600&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 123300.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_819b24c4e1d82d7dbc8bf9794b1b9b00);
#
#
#             circle_cd5b1df9199f38c383457ba51d9e7a9c.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;h5&gt;Maharashtra&lt;/h5&gt;&lt;li&gt;Confirmed:246600&lt;/li&gt;&lt;li&gt;Recovered:136985&lt;/li&gt;&lt;li&gt;Deaths:10116&lt;/li&gt;&lt;li&gt;Active:99202&lt;/li&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_5a7c1f318f5f29313f69eec0a810b00f = L.circle(
#                 [11.1271, 78.6569],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff6600&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 67113.0, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_819b24c4e1d82d7dbc8bf9794b1b9b00);
#
#
#             circle_5a7c1f318f5f29313f69eec0a810b00f.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;h5&gt;Tamil Nadu&lt;/h5&gt;&lt;li&gt;Confirmed:134226&lt;/li&gt;&lt;li&gt;Recovered:85915&lt;/li&gt;&lt;li&gt;Deaths:1898&lt;/li&gt;&lt;li&gt;Active:46413&lt;/li&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_324006d345c0d64525823b1b3922b0e0 = L.circle(
#                 [28.7041, 77.1025],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff6600&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 55460.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_819b24c4e1d82d7dbc8bf9794b1b9b00);
#
#
#             circle_324006d345c0d64525823b1b3922b0e0.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;h5&gt;Delhi&lt;/h5&gt;&lt;li&gt;Confirmed:110921&lt;/li&gt;&lt;li&gt;Recovered:87692&lt;/li&gt;&lt;li&gt;Deaths:3334&lt;/li&gt;&lt;li&gt;Active:19895&lt;/li&gt;
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var circle_58e343ea3d34931f1eae81cc91a25e71 = L.circle(
#                 [22.2587, 71.1924],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#ff6600&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#ff6600&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 20513.5, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_819b24c4e1d82d7dbc8bf9794b1b9b00);
#
#
#             circle_58e343ea3d34931f1eae81cc91a25e71.bindTooltip(
#                 `&lt;div&gt;
#                      &lt;h5&gt;Gujarat&lt;/h5&gt;&lt;li&gt;Confirmed:41027&lt;/li&gt;&lt;li&gt;Recovered:28685&lt;/li&gt;&lt;li&gt;Deaths:2033&lt;/li&gt;&lt;li&gt;Active:10309&lt;/l

# %%
len(df_india[df_india['confirmed']>0].index)
# Out:
# 35
